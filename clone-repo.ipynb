# %% [markdown]
# # Cloning the GitHub repository
# This notebook will clone the GitHub repository to your own Google Drive. The repository will be cloned to `folderName`, which is set to "Colab notebooks" by default, but you can change it by changing the `folderName` variable. Note that `git clone` will create a subfolder called "SACAC-EDA-2024" automatically, so in the example below, the repo will be cloned to `/content/drive/MyDrive/ColabNotebooks/SACAC-EDA-2024`

# %%
from google.colab import drive
drive.mount('/content/drive')

folderName = 'ColabNotebooks'

# %cd /content/drive/MyDrive/
# %mkdir $folderName
# %cd $folderName
# !git clone https://github.com/tmlouw/SACAC-EDA-2024.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# /content/drive/MyDrive/ColabNotebooks
# Cloning into 'SACAC-EDA-2024'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (13/13), 359.93 KiB | 1.51 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# # Updating the repository
# If you have previously cloned the repository into your Google Drive, but you'd like to update it, you can do so using a pull request

# %%
from google.colab import drive
drive.mount('/content/drive')

folderName = 'ColabNotebooks'

# %cd /content/drive/MyDrive/
# %cd $folderName
# %cd SACAC-EDA-2024
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/ColabNotebooks
# /content/drive/MyDrive/ColabNotebooks/SACAC-EDA-2024
# Already up to date.

# %%
# !git config --global user.email "tmlouw@sun.ac.za"
# !git config --global user.name "tmlouw"
# !git add "clone-repo.ipynb"
# !git commit -m "Added the `clone-repo` notebook"
# !git push origin main
# Out:
# /bin/bash: line 1: clone-repo: command not found
# [main 96b65f1] Added the  notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
# fatal: could not read Username for 'https://github.com': No such device or address
